# %%
import pandas as pd
import numpy as np
import time

# %%
df = pd.read_csv("https://raw.githubusercontent.com/sharmaroshan/Social-Networks-Ads/master/Social_Network_Ads.csv")
df.head()
# Out:
#     User ID  Gender   Age  EstimatedSalary  Purchased
# 0  15624510    Male  19.0          19000.0          0
# 1  15810944    Male  35.0          20000.0          0
# 2  15668575  Female  26.0          43000.0          0
# 3  15603246  Female  27.0          57000.0          0
# 4  15804002    Male  19.0          76000.0          0

# %%
df.drop(columns = ['User ID','Gender'],inplace= True)

# %%
df.head()
# Out:
#     Age  EstimatedSalary  Purchased
# 0  19.0          19000.0          0
# 1  35.0          20000.0          0
# 2  26.0          43000.0          0
# 3  27.0          57000.0          0
# 4  19.0          76000.0          0

# %%
X = df.iloc[:,0:2]
y = df.iloc[:,-1]

# %%
X
# Out:
#       Age  EstimatedSalary
# 0    19.0          19000.0
# 1    35.0          20000.0
# 2    26.0          43000.0
# 3    27.0          57000.0
# 4    19.0          76000.0
# ..    ...              ...
# 395  46.0          41000.0
# 396  51.0          23000.0
# 397  50.0          20000.0
# 398  36.0          33000.0
# 399  49.0          36000.0
#
# [400 rows x 2 columns]

# %%
y
# Out:
# 0      0
# 1      0
# 2      0
# 3      0
# 4      0
#       ..
# 395    1
# 396    1
# 397    1
# 398    0
# 399    1
# Name: Purchased, Length: 400, dtype: int64

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()

# %%
X_scaled = scaler.fit_transform(X)

# %%
X_scaled.shape
# Out:
# (400, 2)

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size =0.2,random_state =2)

# %%
X_train.shape
# Out:
# (320, 2)

# %%
import tensorflow as tf
from tensorflow import keras
from keras import Sequential
from keras.layers import Dense

# %%
model = Sequential()

model.add(Dense(10,activation = 'relu',input_dim = 2))
model.add(Dense(10,activation = 'relu'))
model.add(Dense(1,activation = 'sigmoid'))

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 10)                30
#
#  dense_1 (Dense)             (None, 10)                110
#
#  dense_2 (Dense)             (None, 1)                 11
#
# =================================================================
# Total params: 151 (604.00 Byte)
# Trainable params: 151 (604.00 Byte)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
model.compile(loss = 'binary_crossentropy',metrics =['accuracy'])

# %%
#train_size = 320
#Gradient descent or vanilla GD or Batch GD
history = model.fit(X_train,y_train,epochs = 10,batch_size =320)
# Out:
# Epoch 1/10
# 1/1 [==============================] - 0s 12ms/step - loss: 1302.0350 - accuracy: 0.3469
# Epoch 2/10
# 1/1 [==============================] - 0s 12ms/step - loss: 1257.9371 - accuracy: 0.3469
# Epoch 3/10
# 1/1 [==============================] - 0s 12ms/step - loss: 1215.3978 - accuracy: 0.3469
# Epoch 4/10
# 1/1 [==============================] - 0s 11ms/step - loss: 1174.2238 - accuracy: 0.3469
# Epoch 5/10
# 1/1 [==============================] - 0s 12ms/step - loss: 1134.2588 - accuracy: 0.3469
# Epoch 6/10
# 1/1 [==============================] - 0s 10ms/step - loss: 1095.1980 - accuracy: 0.3469
# Epoch 7/10
# 1/1 [==============================] - 0s 10ms/step - loss: 1051.4055 - accuracy: 0.3469
# Epoch 8/10
# 1/1 [==============================] - 0s 14ms/step - loss: 1008.5645 - accuracy: 0.3469
# Epoch 9/10
# 1/1 [==============================] - 0s 11ms/step - loss: 966.3458 - accuracy: 0.3469
# Epoch 10/10
# 1/1 [==============================] - 0s 10ms/step - loss: 924.6902 - accuracy: 0.3469

# %%
#sgd
history = model.fit(X_train,y_train,epochs = 10,batch_size =1)
# Out:
# Epoch 1/10
# 320/320 [==============================] - 3s 5ms/step - loss: 104.8622 - accuracy: 0.4563
# Epoch 2/10
# 320/320 [==============================] - 1s 4ms/step - loss: 66.4085 - accuracy: 0.5219
# Epoch 3/10
# 320/320 [==============================] - 1s 4ms/step - loss: 65.3332 - accuracy: 0.5125
# Epoch 4/10
# 320/320 [==============================] - 1s 4ms/step - loss: 62.9104 - accuracy: 0.4750
# Epoch 5/10
# 320/320 [==============================] - 1s 4ms/step - loss: 61.3639 - accuracy: 0.4656
# Epoch 6/10
# 320/320 [==============================] - 1s 4ms/step - loss: 53.5137 - accuracy: 0.5312
# Epoch 7/10
# 320/320 [==============================] - 1s 4ms/step - loss: 51.9502 - accuracy: 0.5156
# Epoch 8/10
# 320/320 [==============================] - 1s 4ms/step - loss: 46.7734 - accuracy: 0.5219
# Epoch 9/10
# 320/320 [==============================] - 1s 4ms/step - loss: 42.6192 - accuracy: 0.5344
# Epoch 10/10
# 320/320 [==============================] - 2s 5ms/step - loss: 38.6204 - accuracy: 0.5219

# %%
#minibatch
#batch size 32 -> 320/32 = 10 batches
history = model.fit(X_train,y_train,epochs = 10,batch_size =32)
# Out:
# Epoch 1/10
# 10/10 [==============================] - 0s 4ms/step - loss: 32.1772 - accuracy: 0.4719
# Epoch 2/10
# 10/10 [==============================] - 0s 4ms/step - loss: 21.8328 - accuracy: 0.5406
# Epoch 3/10
# 10/10 [==============================] - 0s 4ms/step - loss: 22.6609 - accuracy: 0.5437
# Epoch 4/10
# 10/10 [==============================] - 0s 5ms/step - loss: 20.1033 - accuracy: 0.5344
# Epoch 5/10
# 10/10 [==============================] - 0s 7ms/step - loss: 26.2620 - accuracy: 0.4906
# Epoch 6/10
# 10/10 [==============================] - 0s 6ms/step - loss: 21.2409 - accuracy: 0.5531
# Epoch 7/10
# 10/10 [==============================] - 0s 6ms/step - loss: 21.0661 - accuracy: 0.5156
# Epoch 8/10
# 10/10 [==============================] - 0s 7ms/step - loss: 22.7184 - accuracy: 0.5469
# Epoch 9/10
# 10/10 [==============================] - 0s 6ms/step - loss: 26.5188 - accuracy: 0.5219
# Epoch 10/10
# 10/10 [==============================] - 0s 8ms/step - loss: 26.1584 - accuracy: 0.4969
